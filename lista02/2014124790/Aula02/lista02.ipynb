# %% [markdown]
# # Aula 02 - Visualização de Dados

# %% [markdown]
# # Exercício 01:
#
# Em determinadas épocas do ano a venda de certos produtos sofre um aumento significativo. Um exemplo disso, são as vendas de sorvete que aumentam bastante no verão. Além do sorvete, outros itens como protetor solar e vestuário de banho podem ganhar maior atenção durante essa época do ano enquanto outros produtos podem não ser tão valorizados. Pensando nisso, crie uma função que, dado duas listas com as quantidades de produtos vendidos ao longo dos 12 meses do ano, crie um gráfico de barras ou linhas mostrando a evolução das vendas dos produtos ao longo dos meses em porcentagem. Ou seja, um gráfico relacionando a porcentagem de produtos vendidos naquele mês em relação ao ano como um todo para as vendas de sorvetes, óculos de sol e casacos.

# %%
from matplotlib import pyplot as plt

#Exemplo:
ice_cream = [3000, 2600, 1400, 1500, 1200, 500, 300, 400, 700, 600, 800, 1900]
sunglasses = [1000, 800, 100, 70, 50, 190, 60, 50, 100, 120, 130, 900]
coats = [10, 20, 80, 120, 100, 500, 900, 780, 360, 100, 120, 20]
labels = ["Jan", "Fev", "Mar", "Abr", "Mai", "Jun", "Jul", "Ago", "Set", "Out", "Nov", "Dez"]

def bar_or_lines(list1, list2, list3):
    auxList1 = [x/sum(list1)*100 for x in list1]
    auxList2 = [x/sum(list1)*100 for x in list2]
    auxList3 = [x/sum(list1)*100 for x in list3]
    plt.plot(labels, auxList1, 'r-', label='Item 1')
    plt.plot(labels, auxList2, 'g-', label='Item 2')
    plt.plot(labels, auxList3, 'b-', label='Item 3')
    plt.legend(loc=9) # loc=9 coloca a legenda na posição 9, ou "top center"
    plt.xlabel("Mês")
    plt.ylabel("Porcentagem")
    plt.title("Evolução das vendas")
    
bar_or_lines(ice_cream, sunglasses, coats)

# %% [markdown]
# # Exercício 02:
#
# Utilizando os mesmos dados do exercício anterior, crie uma função que, dado duas listas com as quantidades de produtos vendidos ao longo dos 12 meses do ano, crie um gráfico de dispersão mostrando a correlação entre as vendas dos dois produtos. Como exemplo, gere três gráficos, a partir das três listas que são dadas. Ou seja, um gráfico relacionando as vendas de sorvetes e óculos de sol, outro relacionando as vendas de sorvetes e casacos e, por fim, um relacionando as vendas de óculos de sol e casacos. Em seguida, discuta sobre os gráficos encontrados no sentido de encontrar uma relação entre as vendas.
#
#
# __Dicas:__
# "_Correlação não é o mesmo que causalidade!_"

# %%
from matplotlib import pyplot as plt

#Exemplo:
ice_cream = [3000, 2600, 1400, 1500, 1200, 500, 300, 400, 700, 600, 800, 1900]
sunglasses = [1000, 800, 100, 70, 50, 190, 60, 50, 100, 120, 130, 900]
coats = [10, 20, 80, 120, 100, 500, 900, 780, 360, 100, 120, 20]
labels = ["Jan", "Fev", "Mar", "Abr", "Mai", "Jun", "Jul", "Ago", "Set", "Out", "Nov", "Dez"]

def scatter(list1, list2):    
    plt.scatter(list1, list2)
    
    # label each point
    for label, itemList1, itemList2 in zip(labels, list1, list2):
        plt.annotate(label,
                     xy=(itemList1, itemList2), # associa o label à sua coordenada x,y
                     xytext=(5, -5), #com um pequeno offset
                     textcoords='offset points')
    
    plt.title("Correlação de vendas entre produtos")
    plt.xlabel("Produto 1")
    plt.ylabel("Produto 2")
    plt.show()
    
scatter(ice_cream, sunglasses)
scatter(ice_cream, coats)
scatter(sunglasses, coats)

# %% [markdown]
# __Discuta sobre os resultados obtidos:__

# %% [markdown]
# Os gráficos obtidos acima mostram que, em alguns momentos, há correlação na quantidade de vendas entre dois determinados produtos. Analisando a correlação da quantidade de sorvetes e óculos de sol vendidos, podemos perceber que existe uma relação da quantidade de vendas dos dois itens com a época do ano. Os meses de dezembro, janeiro e fevereiro apresentam um alto volume de vendas de ambos os itens, sugerindo uma relação entre eles com o período de alta nas vendas.
# O segundo gráfico mostra que as vendas de casacos e sorvetes são inversamente proporcionais no decorrer do tempo e mais uma vez a variação na quantidade vendida acompanha as estações do ano, o que faz sentido considerando a mudança de temperatura e como o consumo desses itens está relacionado à mesma.
# Já o terceiro gráfico não sugere uma forte correlação entre a quantidade de óculos de sol e casacos vendidos durante maior parte do tempo, com exceção dos meses de dez/jan/fev, onde se vende muitos óculos e poucos casacos (um comportamento esperado no verão).

# %% [markdown]
# # Exercício 03:
#
#
# Crie uma matriz `n x m` com valores aleatórios positivos e negativos e, em seguida, gere um mapa de calor (_Heatmap_) com uma escala de cores gerada de forma que a cor branca represente o 0.

# %%
import numpy as np
import matplotlib
import random

#Exemplo:
A = [[6, -3], [-4, 8]]
rand_matrix = np.random.randint(-100, 100, size=(random.randint(2, 10),random.randint(2, 10)))

def heatmap(matrix):    
    if matrix.max() > abs(matrix.min()):
        max_value = matrix.max()
        min_value = matrix.max() * -1
    elif abs(matrix.min()) > matrix.max():
        max_value = matrix.min() * -1
        min_value = matrix.min()

    
    plt.imshow(matrix, vmin=min_value, vmax=max_value, cmap='RdGy')
    plt.colorbar()
    plt.show()

heatmap(rand_matrix)
